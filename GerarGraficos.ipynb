# %%
import matplotlib.pyplot as plt
import numpy as np

def gerarEixoX(valor_maximo_x):
  eixo_x = []
  for i in range(valor_maximo_x):
        eixo_x.append(i)
  return eixo_x

# %% [markdown]
# **Gerar Gráficos -**
#
# Eixo X = Amplitude dos testes.
#
# Eixo Y = Tempo em ms

# %%
# lista dos tempos em milissegundos :
eixo_y = 
# eixo_X
eixo_x = gerarEixoX()
# código para gerar gráficos
# plt.plot ( eixo x, eixo y, tipo de reta)
plt.plot(eixo_x, eixo_y,'g-',linewidth=2)
plt.title(' Sort -  ')
plt.xlabel("Amplitude do Teste")
plt.ylabel("Tempo em milissegundos")
plt.grid()
plt.show()
